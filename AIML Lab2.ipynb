# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\CSE Lab\OneDrive\Desktop\student_data.csv")
print("First 5 records:\n" , df.head())
print("\nLast 5 records:\n" , df.tail())
print("\nNumber of rows and columns:" , df.shape)
print("\nColumns:" , df.columns)
print("\nType of columns:\n" , df.dtypes)
print("\nDataset information:" , df.info())
# Out:
# First 5 records:
#     RollNo     Name   Gender    Attebdence    InternalMarks    ExternalMarks
# 0      101    Ravi        M             85               32              55
# 1      102   Priya        F             92               38              58
# 2      103   Kiran        M             78               28              45
# 3      104     Anu        F             95               40              60
# 4      105   Sirta        F             88               35              54
#
# Last 5 records:
#     RollNo       Name   Gender    Attebdence    InternalMarks    ExternalMarks
# 5      106       Raj        M             70               25              40
# 6      107     Divya        F             90               37              57
# 7      108      Arun        M             82               30              48
# 8      109   Keerthi        F             96               39              59
# 9      110    nAVEEN        m             75               27              44
#
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\CSE Lab\OneDrive\Desktop\student_data.csv")
print("Attendence:" , df["Attendence"].mean())
print("\nAverage internal marks:" , df["InternalMarks"].mean())
print("\nAverage external marks:" , df["ExternalMarks"].mean())
print("\nMaximum internal marks:" , df["InternalMarks"].max())
print("\nMinmum internal marks:" , df["InternalMarks"].min())
print("\nMaximum external marks:" , df["ExternalMarks"].max())
print("\nMinimum external marks:" , df["ExternalMarks"].min())
print("\nStandard deviation of  internal marks:" , df["InternalMarks"].std())
print("\nSummary Statistics:\n" , df.describe())
# Out:
# Attendence: 85.1
#
# Average internal marks: 33.1
#
# Average external marks: 52.0
#
# Maximum internal marks: 40
#
# Minmum internal marks: 25
#
# Maximum external marks: 60
#
# Minimum external marks: 40
#
# Standard deviation of  internal marks: 5.425249610233001
#
# Summary Statistics:
#            RollNo  Attendence  InternalMarks  ExternalMarks
# count   10.00000   10.000000       10.00000      10.000000
# mean   105.50000   85.100000       33.10000      52.000000
# std      3.02765    8.736259        5.42525       7.149204
# min    101.00000   70.000000       25.00000      40.000000
# 25%    103.25000   79.000000       28.50000      45.750000
# 50%    105.50000   86.500000       33.50000      54.500000
# 75%    107.75000   91.500000       37.75000      57.750000
# max    110.00000   96.000000       40.00000      60.000000

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\CSE Lab\OneDrive\Desktop\student_data.csv")
df["TotalMarks"] = df["InternalMarks"] + df["ExternalMarks"]
df["Percentage"] = (df["TotalMarks"] / 100) * 100
print(df)
# Out:
#    RollNo     Name Gender  Attendence  InternalMarks  ExternalMarks  \
# 0     101     Ravi      M          85             32             55
# 1     102    Priya      F          92             38             58
# 2     103    Kiran      M          78             28             45
# 3     104      Anu      F          95             40             60
# 4     105    Sirta      F          88             35             54
# 5     106      Raj      M          70             25             40
# 6     107    Divya      F          90             37             57
# 7     108     Arun      M          82             30             48
# 8     109  Keerthi      F          96             39             59
# 9     110   Naveen      M          75             27             44
#
#    TotalMarks  Percentage
# 0          87        87.0
# 1          96        96.0
# 2          73        73.0
# 3         100       100.0
# 4          89        89.0
# 5          65        65.0
# 6          94        94.0
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\CSE Lab\OneDrive\Desktop\student_data.csv")
df["TotalMarks"] = df["InternalMarks"] + df["ExternalMarks"]
highattendence =  df[df["Attendence"] > 90]
print("\nAttendence > 90:")
highattendence
highmarks = df[df["TotalMarks"] > 90]
print("\nMarks > 90 :")
highmarks
# Out:
# Attendence > 90:
#
# Marks > 90 :
#    RollNo     Name Gender  Attendence  InternalMarks  ExternalMarks  \
# 1     102    Priya      F          92             38             58
# 3     104      Anu      F          95             40             60
# 6     107    Divya      F          90             37             57
# 8     109  Keerthi      F          96             39             59
#
#    TotalMarks
# 1          96
# 3         100
# 6          94
# 8          98
