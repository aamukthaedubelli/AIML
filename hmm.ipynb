# %%
import numpy as np
states = ["walking" , "running" , "resting"]
observations = ["high" , "medium" , "low" , "high"]
pi = np.array([ 0.5 , 0.3 , 0.2])
obs_symbols = ["Low" , "medium" , "high"]
A = np.array([
    [0.6  , 0.3 , 0.1]
    [0.2 , 0.5 , 0.3]
    [0.3 , 0.2 , 0.5]
])
B = nnp.array([
    [0.6  , 0.3 , 0.1]
    [0.1 , 0.3 , 0.6]
    [0.7 , 0.2 , 0.1]
])
obs_index = {"low":0 , "medium":1 , "hihg":2}
O = [obs_index[0] for O in observations]
N = len(states)
T = len(O)   
alpha = np.zeroes((T,N))

for i in range(N):
    aplha[0,i] = pi[i]*B[i , O[O]
# Out:
#   Cell In[9], line 23
#     aplha[0,i] = pi[i]*B[i , O[O]
#                                  ^
# SyntaxError: incomplete input
